# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
study_day = '18'
study_model = 'GFS'

# %%
comparision_file = './comparision data/' + study_day + '-enero-2021-' + study_model

# %%
metrics_file = './comparision data/' + study_day + '-enero-2021-' + study_model + '-Metrics'

# %%
comparision_data = pd.read_csv(comparision_file)
comparision_data
# Out:
#    real_data  forecasted_data
# 0   13779.89      7601.915997
# 1   32794.67     32657.760410
# 2   24352.89     38332.514757
# 3     609.77      2983.995098

# %%
metrics = pd.read_csv(metrics_file)
metrics
# Out:
#             MSE         RMSE      MSLE     RMSLE          MAE
# 0  5.981324e+07  7733.901993  0.769233  0.877059  5667.183362

# %%
from glob import glob

# %%
stock_files = sorted(glob('./comparision data/**-Enero-2021-GFS'))
stock_files
# Out:
# ['./comparision data/18-Enero-2021-GFS',
#  './comparision data/19-Enero-2021-GFS',
#  './comparision data/20-Enero-2021-GFS',
#  './comparision data/21-Enero-2021-GFS',
#  './comparision data/22-Enero-2021-GFS',
#  './comparision data/23-Enero-2021-GFS',
#  './comparision data/24-Enero-2021-GFS',
#  './comparision data/25-Enero-2021-GFS',
#  './comparision data/26-Enero-2021-GFS',
#  './comparision data/27-Enero-2021-GFS',
#  './comparision data/28-Enero-2021-GFS',
#  './comparision data/29-Enero-2021-GFS',
#  './comparision data/30-Enero-2021-GFS',
#  './comparision data/31-Enero-2021-GFS']

# %%
Jan_18_to_31_comparission_GFS = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in stock_files), ignore_index=True)

# %%
Jan_18_to_31_comparission_GFS.plot()
plt.ylabel('Power (W)')
plt.title('Comparision Between Pvlib GFS and PV Cutonala from January 18 to 31')
# Out:
# Text(0.5, 1.0, 'Comparision Between Pvlib GFS and PV Cutonala from January 18 to 31')

# %%
metrics_stock_files_GFS = sorted(glob('./comparision data/**-Enero-2021-GFS-Metrics'))
metrics_stock_files_GFS
# Out:
# ['./comparision data/18-Enero-2021-GFS-Metrics',
#  './comparision data/19-Enero-2021-GFS-Metrics',
#  './comparision data/20-Enero-2021-GFS-Metrics',
#  './comparision data/21-Enero-2021-GFS-Metrics',
#  './comparision data/22-Enero-2021-GFS-Metrics',
#  './comparision data/23-Enero-2021-GFS-Metrics',
#  './comparision data/24-Enero-2021-GFS-Metrics',
#  './comparision data/25-Enero-2021-GFS-Metrics',
#  './comparision data/26-Enero-2021-GFS-Metrics',
#  './comparision data/27-Enero-2021-GFS-Metrics',
#  './comparision data/28-Enero-2021-GFS-Metrics',
#  './comparision data/29-Enero-2021-GFS-Metrics',
#  './comparision data/30-Enero-2021-GFS-Metrics',
#  './comparision data/31-Enero-2021-GFS-Metrics']

# %%
Jan_18_to_31_metrics_GFS = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in metrics_stock_files_GFS), ignore_index=True)

# %%
Jan_18_to_31_metrics_GFS.describe()
# Out:
#                 MSE          RMSE       MSLE      RMSLE           MAE
# count  1.400000e+01     14.000000  14.000000  14.000000     14.000000
# mean   7.703184e+07   7221.345438   0.411885   0.592551   5801.083808
# std    9.235971e+07   5176.694038   0.335638   0.255819   4113.352086
# min    2.122318e+06   1456.817795   0.043039   0.207458   1303.650354
# 25%    7.139993e+06   2518.070508   0.201089   0.448417   2160.122770
# 50%    4.183663e+07   6455.508676   0.281731   0.530620   5634.588140
# 75%    9.209377e+07   9596.050850   0.611494   0.779573   7714.920193
# max    2.857692e+08  16904.710210   1.166526   1.080059  14306.027329

# %%
stock_files_NAM = sorted(glob('./comparision data/**-Enero-2021-NAM'))
stock_files_NAM
# Out:
# ['./comparision data/18-Enero-2021-NAM',
#  './comparision data/19-Enero-2021-NAM',
#  './comparision data/20-Enero-2021-NAM',
#  './comparision data/21-Enero-2021-NAM',
#  './comparision data/22-Enero-2021-NAM',
#  './comparision data/23-Enero-2021-NAM',
#  './comparision data/24-Enero-2021-NAM',
#  './comparision data/25-Enero-2021-NAM',
#  './comparision data/26-Enero-2021-NAM',
#  './comparision data/27-Enero-2021-NAM',
#  './comparision data/28-Enero-2021-NAM',
#  './comparision data/29-Enero-2021-NAM',
#  './comparision data/30-Enero-2021-NAM',
#  './comparision data/31-Enero-2021-NAM']

# %%
Jan_18_to_31_comparission_NAM = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in stock_files_NAM), ignore_index=True)

# %%
Jan_18_to_31_comparission_NAM.plot()
plt.ylabel('Power (W)')
plt.title('Comparision Between Pvlib NAM and PV Cutonala from January 18 to 31')
# Out:
# Text(0.5, 1.0, 'Comparision Between Pvlib NAM and PV Cutonala from January 18 to 31')

# %%
metrics_stock_files_NAM = sorted(glob('./comparision data/**-Enero-2021-NAM-Metrics'))
metrics_stock_files_NAM
# Out:
# ['./comparision data/18-Enero-2021-NAM-Metrics',
#  './comparision data/19-Enero-2021-NAM-Metrics',
#  './comparision data/20-Enero-2021-NAM-Metrics',
#  './comparision data/21-Enero-2021-NAM-Metrics',
#  './comparision data/22-Enero-2021-NAM-Metrics',
#  './comparision data/23-Enero-2021-NAM-Metrics',
#  './comparision data/24-Enero-2021-NAM-Metrics',
#  './comparision data/25-Enero-2021-NAM-Metrics',
#  './comparision data/26-Enero-2021-NAM-Metrics',
#  './comparision data/27-Enero-2021-NAM-Metrics',
#  './comparision data/28-Enero-2021-NAM-Metrics',
#  './comparision data/29-Enero-2021-NAM-Metrics',
#  './comparision data/30-Enero-2021-NAM-Metrics',
#  './comparision data/31-Enero-2021-NAM-Metrics']

# %%
Jan_18_to_31_metrics_NAM = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in metrics_stock_files_NAM), ignore_index=True)

# %%
Jan_18_to_31_metrics_NAM.describe()
# Out:
#                 MSE         RMSE       MSLE      RMSLE          MAE
# count  1.400000e+01    14.000000  14.000000  14.000000    14.000000
# mean   1.441814e+07  3260.122022   0.214074   0.445152  2523.743381
# std    1.659832e+07  2020.213619   0.124166   0.130913  1382.172769
# min    2.133298e+06  1460.581421   0.040352   0.200878  1210.725932
# 25%    2.572388e+06  1603.761380   0.149124   0.386154  1376.825911
# 50%    4.689965e+06  2137.167588   0.202500   0.449986  1859.220646
# 75%    2.318566e+07  4813.005586   0.228119   0.477513  3525.242993
# max    5.961836e+07  7721.292401   0.525023   0.724585  5434.597733

# %%
stock_files_RAP = sorted(glob('./comparision data/**-Enero-2021-RAP'))
stock_files_RAP
# Out:
# ['./comparision data/18-Enero-2021-RAP',
#  './comparision data/19-Enero-2021-RAP',
#  './comparision data/20-Enero-2021-RAP',
#  './comparision data/21-Enero-2021-RAP',
#  './comparision data/22-Enero-2021-RAP',
#  './comparision data/23-Enero-2021-RAP',
#  './comparision data/24-Enero-2021-RAP',
#  './comparision data/25-Enero-2021-RAP',
#  './comparision data/26-Enero-2021-RAP',
#  './comparision data/27-Enero-2021-RAP',
#  './comparision data/28-Enero-2021-RAP',
#  './comparision data/29-Enero-2021-RAP',
#  './comparision data/30-Enero-2021-RAP',
#  './comparision data/31-Enero-2021-RAP']

# %%
Jan_18_to_31_comparission_RAP = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in stock_files_RAP), ignore_index=True)

# %%
Jan_18_to_31_comparission_RAP.plot()
plt.ylabel('Power (W)')
plt.title('Comparision Between Pvlib RAP and PV Cutonala from January 18 to 31')
# Out:
# Text(0.5, 1.0, 'Comparision Between Pvlib RAP and PV Cutonala from January 18 to 31')

# %%
metrics_stock_files_RAP = sorted(glob('./comparision data/**-Enero-2021-RAP-Metrics'))
metrics_stock_files_RAP
# Out:
# ['./comparision data/18-Enero-2021-RAP-Metrics',
#  './comparision data/19-Enero-2021-RAP-Metrics',
#  './comparision data/20-Enero-2021-RAP-Metrics',
#  './comparision data/21-Enero-2021-RAP-Metrics',
#  './comparision data/22-Enero-2021-RAP-Metrics',
#  './comparision data/23-Enero-2021-RAP-Metrics',
#  './comparision data/24-Enero-2021-RAP-Metrics',
#  './comparision data/25-Enero-2021-RAP-Metrics',
#  './comparision data/26-Enero-2021-RAP-Metrics',
#  './comparision data/27-Enero-2021-RAP-Metrics',
#  './comparision data/28-Enero-2021-RAP-Metrics',
#  './comparision data/29-Enero-2021-RAP-Metrics',
#  './comparision data/30-Enero-2021-RAP-Metrics',
#  './comparision data/31-Enero-2021-RAP-Metrics']

# %%
Jan_18_to_31_metrics_RAP = pd.concat((pd.read_csv(file).assign(filename = file)
          for file in metrics_stock_files_RAP), ignore_index=True)

# %%
Jan_18_to_31_metrics_RAP.describe()
# Out:
#                 MSE          RMSE       MSLE      RMSLE           MAE
# count  1.400000e+01     14.000000  14.000000  14.000000     14.000000
# mean   5.570849e+07   5965.570587   0.434208   0.614370   4570.641991
# std    7.225690e+07   4654.909999   0.321954   0.247231   3518.100724
# min    2.432797e+06   1559.742460   0.043494   0.208553   1355.638035
# 25%    3.106149e+06   1762.416722   0.204087   0.451707   1609.583056
# 50%    2.298570e+07   4773.916484   0.319892   0.561419   3647.446718
# 75%    6.309947e+07   7940.462127   0.636597   0.795791   5907.422729
# max    2.039204e+08  14280.068587   1.005530   1.002761  10970.461450
